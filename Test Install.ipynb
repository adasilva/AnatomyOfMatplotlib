# %%
import sys
if not sys.version_info.major == 3:
    print('You are using python 2. You may notice some incompatibilities, please upgrade to python3 if possible')

# %%
import pandas as pd

# %%
import matplotlib
from matplotlib import pyplot as plt

if matplotlib.__version__ < '1.5':
    print('Matplotlib needs to be updated')

plt.plot([1, 2, 3, 2, 1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
